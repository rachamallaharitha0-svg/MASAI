# %% [markdown]
# <a href="https://colab.research.google.com/github/rachamallaharitha0-svg/MASAI/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

# Initialize raw synthetic dataset
df = pd.DataFrame({
    'customer_id': [1, 2, 3, 4, 2, 5],
    'age':         [25, np.nan, 35, np.nan, np.nan, 40],
    'city':        ['Mumbai', 'Delhi', np.nan, 'Mumbai', 'Delhi', np.nan],
    'gender':      ['Male', 'Female', 'Female', 'Male', 'Female', 'Male'],
    'annual_income': [40000, 80000, 60000, 120000, 80000, 95000]
})

# ==========================================
# Task 1 — Clean the Data
# ==========================================

# Impute missing age with the median
df['age'] = df['age'].fillna(df['age'].median())

# Impute missing city with the mode (most frequent value)
df['city'] = df['city'].fillna(df['city'].mode()[0])

# Remove duplicate rows
df = df.drop_duplicates()

# Keep a clean copy for the separate scaling task
df_cleaned = df.copy()


# ==========================================
# Task 2 — Encode Categorical Columns
# ==========================================

# One-Hot Encoding for city
df_encoded = pd.get_dummies(df, columns=['city'], dtype=int)

# Label Encoding for gender
le = LabelEncoder()
df_encoded['gender'] = le.fit_transform(df_encoded['gender'])

print("--- Task 2: Encoded Dataframe ---")
print(df_encoded)


# ==========================================
# Task 3 — Scale Numerical Features
# ==========================================
features = ['age', 'annual_income']

# Min-Max Scaling (0 to 1 range)
df_minmax = df_cleaned.copy()
df_minmax[features] = MinMaxScaler().fit_transform(df_minmax[features])

print("\n--- Task 3: Min-Max Scaled Dataframe ---")
print(df_minmax)

# Standardisation (Mean = 0, Variance = 1)
df_std = df_cleaned.copy()
df_std[features] = StandardScaler().fit_transform(df_std[features])

print("\n--- Task 3: Standardised Dataframe ---")
print(df_std)
# Out:
# --- Task 2: Encoded Dataframe ---
#    customer_id   age  gender  annual_income  city_Delhi  city_Mumbai
# 0            1  25.0       1          40000           0            1
# 1            2  35.0       0          80000           1            0
# 2            3  35.0       0          60000           1            0
# 3            4  35.0       1         120000           0            1
# 5            5  40.0       1          95000           1            0
#
# --- Task 3: Min-Max Scaled Dataframe ---
#    customer_id       age    city  gender  annual_income
# 0            1  0.000000  Mumbai    Male         0.0000
# 1            2  0.666667   Delhi  Female         0.5000
# 2            3  0.666667   Delhi  Female         0.2500
# 3            4  0.666667  Mumbai    Male         1.0000
# 5            5  1.000000   Delhi    Male         0.6875
#
# --- Task 3: Standardised Dataframe ---
#    customer_id       age    city  gender  annual_income
# ...
