# %% [markdown]
# <a href="https://colab.research.google.com/github/rachamallaharitha0-svg/MASAI/blob/main/courses/udacity_intro_to_tensorflow_for_deep_learning/l01c01_introduction_to_colab_and_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#To install a library ,use the'pip install'command

# %%
# To install a library, use the `pip install` command.
# For example, to install the pandas library, you would run:
# !pip install pandas

# You can also install multiple libraries at once:
# !pip install numpy matplotlib scipy

# After installation, you can import and use the library in subsequent cells.
import pandas as pd
print('pandas is installed and imported!')
